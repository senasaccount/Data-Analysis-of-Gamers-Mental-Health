# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"/content/GamingStudy_Data.csv", encoding_errors='replace')

# %%
df.head()
# Out:
#    S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 0       1  42052.00437     0     0     0     0     1     0     0
# 1       2  42052.00680     1     2     2     2     0     1     0
# 2       3  42052.03860     0     2     2     0     0     3     1
# 3       4  42052.06804     0     0     0     0     0     0     0
# 4       5  42052.08948     2     1     2     2     2     3     2
#
#                    GADE  ...  Birthplace    Residence  Reference  \
# 0  Not difficult at all  ...         USA          USA     Reddit
# 1    Somewhat difficult  ...         USA          USA     Reddit
# 2  Not difficult at all  ...     Germany      Germany     Reddit
# 3  Not difficult at all  ...         USA          USA     Reddit
# 4        Very difficult  ...         USA  South Korea     Reddit
#
#                                            Playstyle  accept GAD_T SWL_T  \
# 0                                       Singleplayer  Accept     1    23
# ...

# %%
df.shape
# Out:
# (13464, 55)

# %%
df.describe().T
# Out:
#                  count          mean          std          min           25%  \
# S. No.         13464.0   7096.839201  4114.478220      1.00000   3532.750000
# Timestamp      13464.0  42054.841222     0.272948  42052.00437  42054.716548
# GAD1           13464.0      0.860963     0.926542      0.00000      0.000000
# GAD2           13464.0      0.673351     0.915724      0.00000      0.000000
# GAD3           13464.0      0.965761     0.982776      0.00000      0.000000
# GAD4           13464.0      0.724079     0.921971      0.00000      0.000000
# GAD5           13464.0      0.488042     0.837014      0.00000      0.000000
# GAD6           13464.0      0.911022     0.931168      0.00000      0.000000
# GAD7           13464.0      0.588755     0.894408      0.00000      0.000000
# SWL1           13464.0      3.720440     1.736264      1.00000      2.000000
# SWL2           13464.0      4.602050     1.696276      1.00000      3.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13464 entries, 0 to 13463
# Data columns (total 55 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   S. No.           13464 non-null  int64
#  1   Timestamp        13464 non-null  float64
#  2   GAD1             13464 non-null  int64
#  3   GAD2             13464 non-null  int64
#  4   GAD3             13464 non-null  int64
#  5   GAD4             13464 non-null  int64
#  6   GAD5             13464 non-null  int64
#  7   GAD6             13464 non-null  int64
#  8   GAD7             13464 non-null  int64
#  9   GADE             12815 non-null  object
#  10  SWL1             13464 non-null  int64
#  11  SWL2             13464 non-null  int64
#  12  SWL3             13464 non-null  int64
#  13  SWL4             13464 non-null  int64
#  14  SWL5             13464 non-null  int64
#  15  Game             13464 non-null  object
#  16  Platform         13464 non-null  object
# ...

# %%
df.isnull().any()
# Out:
# S. No.             False
# Timestamp          False
# GAD1               False
# GAD2               False
# GAD3               False
# GAD4               False
# GAD5               False
# GAD6               False
# GAD7               False
# GADE                True
# SWL1               False
# SWL2               False
# SWL3               False
# SWL4               False
# SWL5               False
# Game               False
# Platform           False
# Hours               True
# earnings           False
# whyplay            False
# League              True
# highestleague       True
# streams             True
# SPIN1               True
# SPIN2               True
# SPIN3               True
# SPIN4               True
# SPIN5               True
# SPIN6               True
# SPIN7               True
# SPIN8               True
# SPIN9               True
# SPIN10              True
# SPIN11              True
# SPIN12              True
# SPIN13              True
# SPIN14              True
# ...

# %%
df.isnull().sum()
# Out:
# S. No.                 0
# Timestamp              0
# GAD1                   0
# GAD2                   0
# GAD3                   0
# GAD4                   0
# GAD5                   0
# GAD6                   0
# GAD7                   0
# GADE                 649
# SWL1                   0
# SWL2                   0
# SWL3                   0
# SWL4                   0
# SWL5                   0
# Game                   0
# Platform               0
# Hours                 30
# earnings               0
# whyplay                0
# League              1838
# highestleague      13464
# streams              100
# SPIN1                124
# SPIN2                154
# SPIN3                140
# SPIN4                159
# SPIN5                166
# SPIN6                156
# SPIN7                138
# SPIN8                144
# SPIN9                158
# SPIN10               160
# SPIN11               187
# SPIN12               168
# SPIN13               187
# SPIN14               156
# ...

# %% [markdown]
# **Data Cleaning**

# %%
df_hours_over_100 = df[df["Hours"]>100]
df_hours_over_100["Hours"].count()
# Out:
# 14

# %%
index_hours_over_100 = df[df["Hours"] > 100].index

# %%
df.drop(index_hours_over_100, inplace=True)

# %%
df_streams_over_40 = df[df['streams']>40]
df_streams_over_40.streams.count()
# Out:
# 178

# %%
index_streams_over_100 = df[df["streams"] > 40].index

# %%
df.drop(index_streams_over_100, inplace=True)

# %%
threshold = len(df)*0.1
threshold
# Out:
# 1327.2

# %%
df.dropna(thresh=threshold, axis=1, inplace=True)

# %%
def impute_median(column):
  return column.fillna(column.median())

# %%
df.Hours = df["Hours"].transform(impute_median)
df.streams = df["streams"].transform(impute_median)
df.SPIN_T = df["SPIN_T"].transform(impute_median) #mode alınacak

# %%
df['GADE'].fillna(df['GADE'].mode().values[0], inplace=True)
df['League'].fillna(str(df['League'].mode().values[0]), inplace=True)
df['SPIN1'].fillna(df['SPIN1'].mode().values[0], inplace=True)
df['SPIN2'].fillna(df['SPIN2'].mode().values[0], inplace=True)
df['SPIN3'].fillna(df['SPIN3'].mode().values[0], inplace=True)
df['SPIN4'].fillna(df['SPIN4'].mode().values[0], inplace=True)
df['SPIN5'].fillna(df['SPIN5'].mode().values[0], inplace=True)
df['SPIN6'].fillna(df['SPIN6'].mode().values[0], inplace=True)
df['SPIN7'].fillna(df['SPIN7'].mode().values[0], inplace=True)
df['SPIN8'].fillna(df['SPIN8'].mode().values[0], inplace=True)
df['SPIN9'].fillna(df['SPIN9'].mode().values[0], inplace=True)
df['SPIN10'].fillna(df['SPIN10'].mode().values[0], inplace=True)
df['SPIN11'].fillna(df['SPIN11'].mode().values[0], inplace=True)
df['SPIN12'].fillna(df['SPIN12'].mode().values[0], inplace=True)
df['SPIN13'].fillna(df['SPIN13'].mode().values[0], inplace=True)
df['SPIN14'].fillna(df['SPIN14'].mode().values[0], inplace=True)
df['SPIN15'].fillna(df['SPIN15'].mode().values[0], inplace=True)
df['SPIN16'].fillna(df['SPIN16'].mode().values[0], inplace=True)
df['SPIN17'].fillna(df['SPIN17'].mode().values[0], inplace=True)
df['SPIN_T'].fillna(df['SPIN_T'].mode().values[0], inplace=True)
df['Narcissism'].fillna((df['Narcissism'].mode().values[0]), inplace=True)
df['Work'].fillna(str(df['Work'].mode().values[0]), inplace=True)
df['Reference'].fillna(str(df['Reference'].mode().values[0]), inplace=True)
df['accept'].fillna(str(df['accept'].mode().values[0]), inplace=True)
df['Residence_ISO3'].fillna(str(df['Residence_ISO3'].mode().values[0]), inplace=True)
df['Birthplace_ISO3'].fillna(str(df['Birthplace_ISO3'].mode().values[0]), inplace=True)

# %%
df.isnull().sum()
# Out:
# S. No.             0
# Timestamp          0
# GAD1               0
# GAD2               0
# GAD3               0
# GAD4               0
# GAD5               0
# GAD6               0
# GAD7               0
# GADE               0
# SWL1               0
# SWL2               0
# SWL3               0
# SWL4               0
# SWL5               0
# Game               0
# Platform           0
# Hours              0
# earnings           0
# whyplay            0
# League             0
# streams            0
# SPIN1              0
# SPIN2              0
# SPIN3              0
# SPIN4              0
# SPIN5              0
# SPIN6              0
# SPIN7              0
# SPIN8              0
# SPIN9              0
# SPIN10             0
# SPIN11             0
# SPIN12             0
# SPIN13             0
# SPIN14             0
# SPIN15             0
# SPIN16             0
# SPIN17             0
# Narcissism         0
# Gender             0
# Age                0
# Work               0
# ...

# %%
df.GADE.value_counts()
# Out:
# Not difficult at all    6790
# Somewhat difficult      5087
# Very difficult           994
# Extremely difficult      401
# Name: GADE, dtype: int64

# %%
GADE_ans = {'Not difficult at all':1, 'Somewhat difficult':2, 'Very difficult':3, 'Extremely difficult':4, 'Very difficu':3}

# %%
df.GADE = [GADE_ans[item] for item in df.GADE]

# %%
df.GADE.head(10)
# Out:
# 0    1
# 1    2
# 2    1
# 3    1
# 4    3
# 5    1
# 6    1
# 7    1
# 8    3
# 9    2
# Name: GADE, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13272 entries, 0 to 13463
# Data columns (total 54 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   S. No.           13272 non-null  int64
#  1   Timestamp        13272 non-null  float64
#  2   GAD1             13272 non-null  int64
#  3   GAD2             13272 non-null  int64
#  4   GAD3             13272 non-null  int64
#  5   GAD4             13272 non-null  int64
#  6   GAD5             13272 non-null  int64
#  7   GAD6             13272 non-null  int64
#  8   GAD7             13272 non-null  int64
#  9   GADE             13272 non-null  int64
#  10  SWL1             13272 non-null  int64
#  11  SWL2             13272 non-null  int64
#  12  SWL3             13272 non-null  int64
#  13  SWL4             13272 non-null  int64
#  14  SWL5             13272 non-null  int64
#  15  Game             13272 non-null  object
#  16  Platform         13272 non-null  object
# ...

# %% [markdown]
# **General overview of the dataframe**

# %%
df.boxplot(column="Hours")

# %%
df["Hours"].hist()

# %%
df.boxplot(column="streams")

# %%
df["streams"].hist()

# %%
df.boxplot(column="GAD_T")

# %%
df["GAD_T"].hist()

# %%
df.boxplot(column="SWL_T")

# %%
df["SWL_T"].hist()

# %%
df.boxplot(column="SPIN_T")

# %%
df["SPIN_T"].hist()

# %%
df.boxplot(column="GADE")

# %%
df["GADE"].hist()

# %%
df.boxplot(column="Age")

# %%
df["Age"].hist()

# %%
df.boxplot(column="Narcissism")

# %%
df["Narcissism"].hist()

# %% [markdown]
# **Determining Outliers of Hours Column**

# %%
df.Hours.quantile([0.25, 0.5, 0.75]) #analiz
# Out:
# 0.25    12.0
# 0.50    20.0
# 0.75    28.0
# Name: Hours, dtype: float64

# %%
Q1_hours = df.Hours.quantile(0.25)
Q2_hours = df.Hours.quantile(0.50)
Q3_hours = df.Hours.quantile(0.75)
IQR_hours = Q3_hours - Q1_hours
IQR_hours
# Out:
# 16.0

# %%
minValueOfHours = Q1_hours - 1.5*IQR_hours
maxValueOfHours = Q3_hours + 1.5*IQR_hours

# %%
minValueOfHours
# Out:
# -12.0

# %%
maxValueOfHours
# Out:
# 52.0

# %%
upper_outlier = df[df["Hours"]>=maxValueOfHours]
upper_outlier['Hours']
# Out:
# 21        60.0
# 108       80.0
# 155       80.0
# 177       70.0
# 432       55.0
#          ...
# 13223    100.0
# 13295     60.0
# 13326     70.0
# 13355     60.0
# 13393     70.0
# Name: Hours, Length: 385, dtype: float64

# %%
df.boxplot(column="Hours")  # Here, we can clearly see the outliers of playing hours. As we determined it's starts with 52

# %% [markdown]
# **Density Plots for Outliers Based on Hour Column**

# %%
df['Gender'].value_counts()
# Out:
# Male      12518
# Female      705
# Other        49
# Name: Gender, dtype: int64

# %%
female_df = df[df['Gender'] == 'Female']
male_df = df[df['Gender'] == 'Male']
other_df = df[df['Gender'] == 'Other']

# %%
uofd = upper_outlier[upper_outlier['Gender'] == 'Female']
uomd = upper_outlier[upper_outlier['Gender'] == 'Male']
uood = upper_outlier[upper_outlier['Gender'] == 'Other']

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 6))
fig.suptitle('Gender Based GAD_T Density Plots', fontweight="bold", fontsize=20)

sns.kdeplot(df.GAD_T, color="maroon", ax = axes[0], label = 'all gamers')
sns.kdeplot(upper_outlier.GAD_T, color="navy", ax = axes[0], label = 'outliers')
axes[0].legend()
axes[0].set_title('all gamers vs. upper outliers GAD_T graph')

sns.kdeplot(female_df.GAD_T, color="maroon", ax = axes[1], label = 'female gamers')
sns.kdeplot(uofd.GAD_T, color="navy", ax = axes[1], label = 'female outliers')
axes[1].legend()
axes[1].set_title('female gamers vs. female upper outliers GAD_T graph')

sns.kdeplot(male_df.GAD_T, color="maroon", ax = axes[2], label = 'male gamers')
sns.kdeplot(uomd.GAD_T, color="navy", ax = axes[2], label = 'male outliers')
axes[2].legend()
axes[2].set_title('male gamers vs. male upper outliers GAD_T graph')
# Out:
# Text(0.5, 1.0, 'male gamers vs. male upper outliers GAD_T graph')

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 6))
fig.suptitle('Gender Based SWL_T Density Plots', fontweight="bold", fontsize=20)

ax = sns.kdeplot(df.SWL_T, color="maroon", ax = axes[0], label = 'all gamers')
ax = sns.kdeplot(upper_outlier.SWL_T, color="navy", ax = axes[0], label = 'outliers')
axes[0].legend()
ax.set_title('all gamers vs. upper outliers SWL_T graph')

ax = sns.kdeplot(female_df.SWL_T, color="maroon", ax = axes[1], label = 'female gamers')
ax = sns.kdeplot(uofd.SWL_T, color="navy", ax = axes[1], label = 'female outliers')
axes[1].legend()
ax.set_title('all gamers vs. upper outliers SWL_T graph')

ax = sns.kdeplot(male_df.SWL_T, color="maroon", ax = axes[2], label = 'male gamers')
ax = sns.kdeplot(uomd.SWL_T, color="navy", ax = axes[2], label = 'male outliers')
axes[2].legend()
ax.set_title('all gamers vs. upper outliers SWL_T graph')
# Out:
# Text(0.5, 1.0, 'all gamers vs. upper outliers SWL_T graph')

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 6))
fig.suptitle('Gender Based SPIN_T Density Plots', fontweight="bold", fontsize=20)

ax = sns.kdeplot(df.SPIN_T, color="maroon", ax = axes[0], label = 'all gamers')
ax = sns.kdeplot(upper_outlier.SPIN_T, color="navy", ax = axes[0], label = 'outliers')
axes[0].legend()
ax.set_title('all gamers vs. upper outliers SPIN_T graph')

ax = sns.kdeplot(female_df.SPIN_T, color="maroon", ax = axes[1], label = 'female gamers')
ax = sns.kdeplot(uofd.SPIN_T, color="navy", ax = axes[1], label = 'female outliers')
axes[1].legend()
ax.set_title('all gamers vs. upper outliers SPIN_T graph')

ax = sns.kdeplot(male_df.SPIN_T, color="maroon", ax = axes[2], label = 'male gamers')
ax = sns.kdeplot(uomd.SPIN_T, color="navy", ax = axes[2], label = 'male outliers')
axes[2].legend()
ax.set_title('all gamers vs. upper outliers SPIN_T graph')
# Out:
# Text(0.5, 1.0, 'all gamers vs. upper outliers SPIN_T graph')

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 6))
fig.suptitle('Gender Based Streams Density Plots', fontweight="bold", fontsize=20)

ax = sns.kdeplot(df.streams, color="maroon", ax = axes[0], label = 'all gamers')
ax = sns.kdeplot(upper_outlier.streams, color="navy", ax = axes[0], label = 'outliers')
axes[0].legend()
ax.set_title('all gamers vs. upper outliers streams graph')

ax = sns.kdeplot(female_df.streams, color="maroon", ax = axes[1], label = 'female gamers')
ax = sns.kdeplot(uofd.streams, color="navy", ax = axes[1], label = 'female outliers')
axes[1].legend()
ax.set_title('all gamers vs. upper outliers streams graph')

ax = sns.kdeplot(male_df.streams, color="maroon", ax = axes[2], label = 'male gamers')
ax = sns.kdeplot(uomd.streams, color="navy", ax = axes[2], label = 'male outliers')
axes[2].legend()
ax.set_title('all gamers vs. upper outliers streams graph')
# Out:
# Text(0.5, 1.0, 'all gamers vs. upper outliers streams graph')

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 6))
fig.suptitle('Gender Based Narcissism Density Plots', fontweight="bold", fontsize=20)

ax = sns.kdeplot(df.Narcissism, color="maroon", ax = axes[0], label = 'all gamers')
ax = sns.kdeplot(upper_outlier.Narcissism, color="navy", ax = axes[0], label = 'outliers')
axes[0].legend()
ax.set_title('all gamers vs. upper outliers Narcissism graph')

ax = sns.kdeplot(female_df.Narcissism, color="maroon", ax = axes[1], label = 'female gamers')
ax = sns.kdeplot(uofd.Narcissism, color="navy", ax = axes[1], label = 'female outliers')
axes[1].legend()
ax.set_title('all gamers vs. upper outliers Narcissism graph')

ax = sns.kdeplot(male_df.Narcissism, color="maroon", ax = axes[2], label = 'male gamers')
ax = sns.kdeplot(uomd.Narcissism, color="navy", ax = axes[2], label = 'male outliers')
axes[2].legend()
ax.set_title('all gamers vs. upper outliers Narcissism graph')
# Out:
# Text(0.5, 1.0, 'all gamers vs. upper outliers Narcissism graph')

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 6))
fig.suptitle('Gender Based Hours Density Plots', fontweight="bold", fontsize=20)

ax = sns.kdeplot(df.Hours, color="maroon", ax = axes[0], label = 'all gamers')
ax = sns.kdeplot(upper_outlier.Hours, color="navy", ax = axes[0], label = 'outliers')
axes[0].legend()
ax.set_title('all gamers vs. upper outliers weekly playing hour graph')

ax = sns.kdeplot(female_df.Hours, color="maroon", ax = axes[1], label = 'female gamers')
ax = sns.kdeplot(uofd.Hours, color="navy", ax = axes[1], label = 'female outliers')
axes[1].legend()
ax.set_title('all gamers vs. upper outliers weekly playing hour graph')

ax = sns.kdeplot(male_df.Hours, color="maroon", ax = axes[2], label = 'male gamers')
ax = sns.kdeplot(uomd.Hours, color="navy", ax = axes[2], label = 'male outliers')
axes[2].legend()
ax.set_title('all gamers vs. upper outliers weekly playing hour graph')
# Out:
# Text(0.5, 1.0, 'all gamers vs. upper outliers weekly playing hour graph')

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 6))
fig.suptitle('Gender Based GADE Density Plots', fontweight="bold", fontsize=20)

ax = sns.kdeplot(df.GADE, color="maroon", ax = axes[0], label = 'all gamers')
ax = sns.kdeplot(upper_outlier.GADE, color="navy", ax = axes[0], label = 'outliers')
axes[0].legend()
ax.set_title('all gamers vs. upper outliers GADE graph')

ax = sns.kdeplot(female_df.GADE, color="maroon", ax = axes[1], label = 'female gamers')
ax = sns.kdeplot(uofd.GADE, color="navy", ax = axes[1], label = 'female outliers')
axes[1].legend()
ax.set_title('all gamers vs. upper outliers GADE graph')

ax = sns.kdeplot(male_df.GADE, color="maroon", ax = axes[2], label = 'male gamers')
ax = sns.kdeplot(uomd.GADE, color="navy", ax = axes[2], label = 'male outliers')
axes[2].legend()
ax.set_title('all gamers vs. upper outliers GADE graph')
# Out:
# Text(0.5, 1.0, 'all gamers vs. upper outliers GADE graph')

# %%
df.whyplay.value_counts()
# Out:
# having fun                                                                          5230
# improving                                                                           4850
# winning                                                                             2046
# relaxing                                                                             649
# All of the above                                                                      26
#                                                                                     ...
# Making my brain go numb                                                                1
# Combination: Winning / Having fun                                                      1
# Improving + Fun                                                                        1
# to be occupied                                                                         1
# Mental priority is Fun>Improve>Win, actual priority once in game Win>Improve>Fun       1
# ...

# %%
having_fun_df = df[df.whyplay == 'having fun']
improving_df = df[df.whyplay == 'improving']
winning_df = df[df.whyplay == 'winning']
relaxing_df = df[df.whyplay == 'relaxing']

# %%
plot = sns.kdeplot(df.GAD_T, color="maroon", label = 'all gamers')
plot = sns.kdeplot(having_fun_df.GAD_T, color="navy", label = 'having fun')
plot = sns.kdeplot(improving_df.GAD_T, color="orange", label = 'improving')
plot = sns.kdeplot(winning_df.GAD_T, color="green", label = 'winning')
plot = sns.kdeplot(relaxing_df.GAD_T, color="magenta", label = 'relaxing')
plot.legend()

# %%
plot = sns.kdeplot(df.SWL_T, color="maroon", label = 'all gamers')
plot = sns.kdeplot(having_fun_df.SWL_T, color="navy", label = 'having fun')
plot = sns.kdeplot(improving_df.SWL_T, color="orange", label = 'improving')
plot = sns.kdeplot(winning_df.SWL_T, color="green", label = 'winning')
plot = sns.kdeplot(relaxing_df.SWL_T, color="magenta", label = 'relaxing')
plot.legend()

# %%
plot = sns.kdeplot(df.SPIN_T, color="maroon", label = 'all gamers')
plot = sns.kdeplot(having_fun_df.SPIN_T, color="navy", label = 'having fun')
plot = sns.kdeplot(improving_df.SPIN_T, color="orange", label = 'improving')
plot = sns.kdeplot(winning_df.SPIN_T, color="green", label = 'winning')
plot = sns.kdeplot(relaxing_df.SPIN_T, color="magenta", label = 'relaxing')
plot.legend()

# %%
plot = sns.kdeplot(df.Narcissism, color="maroon", label = 'all gamers')
plot = sns.kdeplot(having_fun_df.Narcissism, color="navy", label = 'having fun')
plot = sns.kdeplot(improving_df.Narcissism, color="orange", label = 'improving')
plot = sns.kdeplot(winning_df.Narcissism, color="green", label = 'winning')
plot = sns.kdeplot(relaxing_df.Narcissism, color="magenta", label = 'relaxing')
plot.legend()

# %%
df.Playstyle.value_counts()
# Out:
# Multiplayer - online - with real life friends                                   5509
# Multiplayer - online - with strangers                                           4060
# Multiplayer - online - with online acquaintances or teammates                   2610
# Singleplayer                                                                     744
# Multiplayer - offline (people in the same room)                                   48
#                                                                                 ...
# With RL friends and randoms                                                        1
# Online with friends, both real life friends and friends I've made online.          1
# Multiplayer - online - with strangers against A.I.                                 1
# Multiplayer equally with strangers or real life friends                            1
# I usually play online with my real life friends and the internet ones alike.       1
# ...

# %%
mo_realFriends = df[df['Playstyle']=='Multiplayer - online - with real life friends']
mo_strangers = df[df['Playstyle']=='Multiplayer - online - with strangers']
mo_onlineFriends = df[df['Playstyle']=='Multiplayer - online - with online acquaintances or teammates']
singlePlayer = df[df['Playstyle']=='Singleplayer']

# %%
plot = sns.kdeplot(df.GAD_T, color="maroon", label = 'all gamers')
plot = sns.kdeplot(mo_realFriends.GAD_T, color="navy", label = 'with real friends')
plot = sns.kdeplot(mo_strangers.GAD_T, color="orange", label = 'with strangers')
plot = sns.kdeplot(mo_onlineFriends.GAD_T, color="green", label = 'with online friends')
plot = sns.kdeplot(singlePlayer.GAD_T, color="magenta", label = 'singleplayers')
plot.legend()

# %%
plot = sns.kdeplot(df.SWL_T, color="maroon", label = 'all gamers')
plot = sns.kdeplot(mo_realFriends.SWL_T, color="navy", label = 'with real friends')
plot = sns.kdeplot(mo_strangers.SWL_T, color="orange", label = 'with strangers')
plot = sns.kdeplot(mo_onlineFriends.SWL_T, color="green", label = 'with online friends')
plot = sns.kdeplot(singlePlayer.SWL_T, color="magenta", label = 'singleplayers')
plot.legend()

# %%
plot = sns.kdeplot(df.SPIN_T, color="maroon", label = 'all gamers')
plot = sns.kdeplot(mo_realFriends.SPIN_T, color="navy", label = 'with real friends')
plot = sns.kdeplot(mo_strangers.SPIN_T, color="orange", label = 'with strangers')
plot = sns.kdeplot(mo_onlineFriends.SPIN_T, color="green", label = 'with online friends')
plot = sns.kdeplot(singlePlayer.SPIN_T, color="magenta", label = 'singleplayers')
plot.legend()

# %%
plot = sns.kdeplot(df.Narcissism, color="maroon", label = 'all gamers')
plot = sns.kdeplot(mo_realFriends.Narcissism, color="navy", label = 'with real friends')
plot = sns.kdeplot(mo_strangers.Narcissism, color="orange", label = 'with strangers')
plot = sns.kdeplot(mo_onlineFriends.Narcissism, color="green", label = 'with online friends')
plot = sns.kdeplot(singlePlayer.Narcissism, color="magenta", label = 'singleplayers')
plot.legend()
